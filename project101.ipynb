# %% [markdown]
# <a href="https://colab.research.google.com/github/basleal22/baslealwork/blob/main/project101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os

# %%
cd /content/drive/MyDrive/project101/
# Out:
# /content/drive/MyDrive/project101

# %%
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/MyDrive/project101/"

# %%
# !kaggle datasets download -d fanconic/skin-cancer-malignant-vs-benign
# Out:
# ...
#  98% 317M/325M [00:03<00:00, 123MB/s]
# 100% 325M/325M [00:03<00:00, 106MB/s]

# %%
import pandas as pd
import zipfile
zip_ref = zipfile.ZipFile('skin-cancer-malignant-vs-benign.zip', 'r')
zip_ref.extractall('/content/drive/MyDrive/project101')
zip_ref.close()

# %%
import os
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

test_dir = '/content/drive/MyDrive/project101/test/benign'  # Replace with the path to your test set directory

# Get a list of image files in the test set directory
image_files = os.listdir(test_dir)

# Select a random image to visualize
random_image = random.choice(image_files)
image_path = os.path.join(test_dir, random_image)

# Read and display the image
img = mpimg.imread(image_path)
plt.imshow(img)
plt.axis('off')
plt.show()
